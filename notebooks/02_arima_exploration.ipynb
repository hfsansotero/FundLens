# %% [markdown]
# # ARIMA Exploration — FundLens
#
# Prototype ARIMA model on VFINX before integrating into `arima_model.py`.

# %%
# Phase 2 notebook — placeholder
# TODO: add pmdarima, auto_arima grid search, walk-forward validation
